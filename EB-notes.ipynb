# %%
#import necessary packages
import pandas as pd
import numpy as np
import os
from urllib.request import urlopen
import json
import cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from scipy import interpolate
from scipy.interpolate import griddata

from pygbif import occurrences as occ

# %% [markdown]
# Using the GBIF API to download iNaturalist data
#
# Jillian: Time range / time series of species
#
# Erica: spatial distribution of a species
# Kiran: Synthesizing iNaturalist data (counts of observations?)

# %%
sb_inat = pd.read_csv("/courses/EDS214/EDS220_gbffs/inat_sb_recent.csv", sep = '\t') #make sure to update the file path to where your data is stored

# %% [markdown]
# Spatial distribution of observations:

# %%
#setting up shp file path for CA state boundary (found online - https://data.ca.gov/dataset/ca-geographic-boundaries/resource/3db1e426-fb51-44f5-82d5-a54d7c6e188b)
shp_data = gpd.read_file("/courses/EDS214/EDS220_gbffs/ca-state-boundary/CA_State_TIGER2016.shp")


#now we want to isolate our table to only observations of class 'Aves'
sb_animals = sb_inat.loc[sb_inat['kingdom'] == "Animalia"] # filter data to just animal observations
sb_animals = gpd.GeoDataFrame(sb_animals)

#need to convert coordinates into actual coordinates, not just data points
obs_coords = gpd.points_from_xy(sb_animals['decimalLongitude'], sb_animals['decimalLatitude'], crs = "EPSG:4326")


sb_animals_gdf = gpd.GeoDataFrame(sb_animals, geometry=obs_coords)
sb_animals_gdf

#need to convert shp file into a lat/lon situation instead of meters
shp_reproj = shp_data.to_crs("epsg:4326") 
shp_reproj.plot()

#defining size of output figure
fig, ax = plt.subplots(figsize=(14,6))

#setting boundaries
xmin = -120.8
xmax = -119.1
ymin = 34
ymax = 35

#feed min and max thru into limits for x and y axis
xlim = (xmin, xmax)
ylim = (ymin, ymax)

#set axis to x and y limits
ax.set_xlim(xlim)
ax.set_ylim(ylim)

#sb map
plt.title("iNaturalist Research-Grade Observations of Birds in Santa Barbara")
shp_reproj.plot(legend = False, ax = ax,
               color = "skyblue")

#sb aves 
sb_animals_gdf.plot(aspect = 1,
               color = "orangered",
                marker = "o",
                 alpha = 0.75,
                 markersize = 0.6,
               ax = ax)

# %%
import shapely 
import geopandas as gpd
import pandas as pd

# Repeated--- read in the data! 
sb_inat = pd.read_csv("/courses/EDS214/EDS220_gbffs/inat_sb_recent.csv", sep = '\t') #make sure to update the file path to where your data is stored


sb_animals = sb_inat.loc[sb_inat['kingdom'] == "Animalia"] # filter data to just animal observations

# %%
# Using shapely, create geometries from your lat-lons
geom_list = [shapely.geometry.Point(lon,lat) for lon,lat in zip(tarantulas["decimalLongitude"] , tarantulas["decimalLatitude"])] # check the ordering of lon/lat

# Create a GeoDataFrame with a point at Bren Hall. 
# Start with a DataFrame...
ucsb_df = pd.DataFrame(
    {'Location': ['Bren Hall'],
     'Latitude': [34.413059],
     'Longitude': [-119.841826]})

# Then use that DataFrame to make a GeoDataFrame
ucsb_gdf = gpd.GeoDataFrame(
    ucsb_df, geometry=gpd.points_from_xy(ucsb_df.Longitude, ucsb_df.Latitude), crs={"init":"EPSG:4326"})

# Reproject this GDF to the same CRS as tarantulas_rpj--- this will allow us to do calculations in meters.
ucsb_gdf = ucsb_gdf.to_crs("EPSG:6423")

# Create a buffer around Bren at 1 mile

ucsb_buffer_1mile = ucsb_gdf.buffer(1609).unary_union # in meters

not_friendly_neighbors = tarantulas_rpj["geometry"].intersection(ucsb_buffer_1mile)

# print all the nearby points
print(tarantulas_rpj[~not_friendly_neighbors.is_empty]) # Yay! No tarantulas within a mile!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 # Using shapely, create geometries from your lat-lons
# ----> 2 geom_list = [shapely.geometry.Point(lon,lat) for lon,lat in zip(tarantulas["decimalLongitude"] , tarantulas["decimalLatitude"])] # check the ordering of lon/lat
#       4 # Create a GeoDataFrame with a point at Bren Hall.
#       5 # Start with a DataFrame...
#       6 ucsb_df = pd.DataFrame(
#       7     {'Location': ['Bren Hall'],
#       8      'Latitude': [34.413059],
#       9      'Longitude': [-119.841826]})
#
# NameError: name 'tarantulas' is not defined

# %%
print(sb_inat.head())
# Out:
#        gbifID                            datasetKey  \
# 0  1703218988  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  2542877676  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  2236229147  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  2826332347  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  2963805574  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID   kingdom        phylum  \
# 0   https://www.inaturalist.org/observations/8964710   Plantae  Tracheophyta
# 1  https://www.inaturalist.org/observations/14123375   Plantae  Tracheophyta
# 2  https://www.inaturalist.org/observations/22100520   Plantae  Tracheophyta
# 3  https://www.inaturalist.org/observations/54560051  Animalia    Arthropoda
# 4  https://www.inaturalist.org/observations/63292703  Animalia      Chordata
#
#            class          order       family        genus  \
# 0  Magnoliopsida        Rosales     Rosaceae  Heteromeles
# 1  Magnoliopsida       Lamiales    Lamiaceae  Trichostema
# 2  Magnoliopsida     Oxalidales  Oxalidaceae       Oxalis
# 3        Insecta    Hymenoptera       Apidae       Bombus
# 4           Aves  Passeriformes     Laniidae       Lanius
#
#                    species  ...        identifiedBy       dateIdentified  \
# 0  Heteromeles arbutifolia  ...  David Vander Pluym  2017-11-28T16:16:36
# 1      Trichostema lanatum  ...        Krissa Klein  2019-12-31T08:40:45
# 2        Oxalis pes-caprae  ...           Jim Riley  2019-04-06T17:58:04
# 3      Bombus vosnesenskii  ...               Carlo  2020-07-27T20:03:46
# 4      Lanius ludovicianus  ...       Dustin Harris  2020-10-23T02:50:46
#
#         license        rightsHolder          recordedBy typeStatus  \
# 0  CC_BY_NC_4_0  David Vander Pluym  David Vander Pluym        NaN
# 1  CC_BY_NC_4_0             dennis1             dennis1        NaN
# 2  CC_BY_NC_4_0           Jim Riley           Jim Riley        NaN
# 3  CC_BY_NC_4_0               Carlo               Carlo        NaN
# 4  CC_BY_NC_4_0       Dustin Harris       Dustin Harris        NaN
#
#    establishmentMeans           lastInterpreted  \
# 0                 NaN  2022-11-11T17:31:27.950Z
# 1                 NaN  2022-11-11T17:31:37.445Z
# 2                 NaN  2022-11-11T17:31:49.498Z
# 3                 NaN  2022-11-11T17:32:46.231Z
# 4                 NaN  2022-11-11T17:33:03.132Z
#
#                                      mediaType               issue
# 0             StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 1                        StillImage;StillImage  COORDINATE_ROUNDED
# 2                                   StillImage  COORDINATE_ROUNDED
# 3  StillImage;StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 4                        StillImage;StillImage  COORDINATE_ROUNDED
#
# [5 rows x 50 columns]

# %% [markdown]
# Investigate how many different users are in the Santa Barbara area

# %%
sb_inat.recordedBy.value_counts().plot(kind='bar') #this is really bad try a different way
# Out:
# /opt/python/3.10.5/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 78218 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/python/3.10.5/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 78218 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
len(sb_inat['recordedBy'].unique()) #There's 5,724 different users in SB!
# Out:
# 5724

# %%
#How active are all of those users? - let's create a histogram to see how many observations are made by the top 100 users
n = 100
top_recorders = sb_inat.recordedBy.value_counts()[:n]

# set three variables, n, bins, and patches
n, bins, patches = plt.hist(x = top_recorders, bins='auto')

# Label plot axes
plt.xlabel('Users')
plt.ylabel('Count')
plt.title("iNaturalist Users Recording Observations Around Santa Barbara")
# Out:
# Text(0.5, 1.0, 'iNaturalist Users Recording Observations Around Santa Barbara')

# %%
top_rcrds = sb_inat.recordedBy.value_counts()[:20] # count observations for each user and return 20 most active

top_rcrds.plot(kind='bar')

# %%
len(sb_inat.recordedBy.unique())

# topusrs = sb_inat.groupby('recordedBy') #group dataframe by users
# topusrs.truncate #truncate to top users by number of observations (>20)
#

# active_recorders = top_re.sort_values('Weather',ascending=False)
# print(sort_by_weather_desc.head(n=3))
# Out:
# 141421

# %%
# Out:
#        gbifID                            datasetKey  \
# 0  1703218988  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  2542877676  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  2236229147  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  2826332347  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  2963805574  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID   kingdom        phylum  \
# 0   https://www.inaturalist.org/observations/8964710   Plantae  Tracheophyta
# 1  https://www.inaturalist.org/observations/14123375   Plantae  Tracheophyta
# 2  https://www.inaturalist.org/observations/22100520   Plantae  Tracheophyta
# 3  https://www.inaturalist.org/observations/54560051  Animalia    Arthropoda
# 4  https://www.inaturalist.org/observations/63292703  Animalia      Chordata
#
#            class          order       family        genus  \
# 0  Magnoliopsida        Rosales     Rosaceae  Heteromeles
# 1  Magnoliopsida       Lamiales    Lamiaceae  Trichostema
# 2  Magnoliopsida     Oxalidales  Oxalidaceae       Oxalis
# 3        Insecta    Hymenoptera       Apidae       Bombus
# 4           Aves  Passeriformes     Laniidae       Lanius
#
#                    species  ...        identifiedBy       dateIdentified  \
# 0  Heteromeles arbutifolia  ...  David Vander Pluym  2017-11-28T16:16:36
# 1      Trichostema lanatum  ...        Krissa Klein  2019-12-31T08:40:45
# 2        Oxalis pes-caprae  ...           Jim Riley  2019-04-06T17:58:04
# 3      Bombus vosnesenskii  ...               Carlo  2020-07-27T20:03:46
# 4      Lanius ludovicianus  ...       Dustin Harris  2020-10-23T02:50:46
#
#         license        rightsHolder          recordedBy typeStatus  \
# 0  CC_BY_NC_4_0  David Vander Pluym  David Vander Pluym        NaN
# 1  CC_BY_NC_4_0             dennis1             dennis1        NaN
# 2  CC_BY_NC_4_0           Jim Riley           Jim Riley        NaN
# 3  CC_BY_NC_4_0               Carlo               Carlo        NaN
# 4  CC_BY_NC_4_0       Dustin Harris       Dustin Harris        NaN
#
#    establishmentMeans           lastInterpreted  \
# 0                 NaN  2022-11-11T17:31:27.950Z
# 1                 NaN  2022-11-11T17:31:37.445Z
# 2                 NaN  2022-11-11T17:31:49.498Z
# 3                 NaN  2022-11-11T17:32:46.231Z
# 4                 NaN  2022-11-11T17:33:03.132Z
#
#                                      mediaType               issue
# 0             StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 1                        StillImage;StillImage  COORDINATE_ROUNDED
# 2                                   StillImage  COORDINATE_ROUNDED
# 3  StillImage;StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 4                        StillImage;StillImage  COORDINATE_ROUNDED
#
# [5 rows x 50 columns]

# %% [markdown]
# Using iNaturalist Research - Grade Observations
# https://www.gbif.org/dataset/50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
# Help for using the API: https://www.gbif.org/developer/summary

# %%
# Read in your token
#iucn_token="9bb4facb6d23f48efbf424bb05c0c1ef1cf6f468393bc745d42179ac4aca5fee"

# Root URL for GBIF API
gbif_url=" https://api.gbif.org/v1/"

#don't need a token, just your username and password for your GBIF account

# %%
from pygbif import species
species.name_suggest(q='Pygoscelis adeliae')

#or look up within the species module using any of these commands:
#species.name_backbone(rank=None, kingdom=None, phylum=None, clazz=None, order=None, family=None, genus=None, strict=False, verbose=False, offset=None, limit=100, **kwargs)


# usrname = "erica-bishop-ucsb"
# password = "p@$$word"
# Out:
# [{'key': 2481663,
#   'nameKey': 9561926,
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Sphenisciformes',
#   'family': 'Spheniscidae',
#   'genus': 'Pygoscelis',
#   'species': 'Pygoscelis adeliae',
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 7190978,
#   'familyKey': 5284,
#   'genusKey': 2481662,
#   'speciesKey': 2481663,
#   'parent': 'Pygoscelis',
#   'parentKey': 2481662,
#   'nubKey': 2481663,
#   'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#   'canonicalName': 'Pygoscelis adeliae',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'higherClassificationMap': {'1': 'Animalia',
#    '44': 'Chordata',
#    '212': 'Aves',
#    '7190978': 'Sphenisciformes',
#    '5284': 'Spheniscidae',
#    '2481662': 'Pygoscelis'},
#   'class': 'Aves'},
#  {'key': 10492546,
#   'nameKey': 9561933,
#   'kingdom': 'incertae sedis',
#   'phylum': 'Cossaviricota',
#   'order': 'Sepolyvirales',
#   'family': 'Polyomaviridae',
#   'genus': 'Gammapolyomavirus',
#   'species': 'Pygoscelis adeliae polyomavirus 1',
#   'kingdomKey': 0,
#   'phylumKey': 10738531,
#   'classKey': 10695749,
#   'orderKey': 10819697,
#   'familyKey': 1935,
#   'genusKey': 10119824,
#   'speciesKey': 10492546,
#   'parent': 'Gammapolyomavirus',
#   'parentKey': 10119824,
#   'scientificName': 'Pygoscelis adeliae polyomavirus 1',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'synonym': False,
#   'higherClassificationMap': {'0': 'incertae sedis',
#    '10738531': 'Cossaviricota',
#    '10695749': 'Papovaviricetes',
#    '10819697': 'Sepolyvirales',
#    '1935': 'Polyomaviridae',
#    '10119824': 'Gammapolyomavirus'},
#   'class': 'Papovaviricetes'}]

# %%
#Lets explore this API investigating penguins!
# Look up names like mammalia
species.name_lookup(q='Spheniscidae')

# Paging
species.name_lookup(q='Spheniscidae', limit=1)
species.name_lookup(q='Spheniscidae', limit=1, offset=2)

# large requests, use offset parameter
first = species.name_lookup(q='Spheniscidae', limit=1000)
second = species.name_lookup(q='Spheniscidae', limit=1000, offset=1000)

# Get all data and parse it, removing descriptions which can be quite long
species.name_lookup('Pygoscelis adeliae', rank="species", verbose=True)

# Get all data and parse it, removing descriptions field which can be quite long
out = species.name_lookup('Pygoscelis adeliae', rank="species")
res = out['results']
[ z.pop('descriptions', None) for z in res ]
res

# Fuzzy searching
# species.name_lookup(q='Heli', rank="genus")

# # Limit records to certain number
# species.name_lookup('Helianthus annuus', rank="species", limit=2)

# # Query by habitat
# species.name_lookup(habitat = "terrestrial", limit=2)
# species.name_lookup(habitat = "marine", limit=2)
# species.name_lookup(habitat = "freshwater", limit=2)

# Using faceting
# species.name_lookup(facet='status', limit=0, facetMincount='70000')
# species.name_lookup(facet=['status', 'higherTaxonKey'], limit=0, facetMincount='700000')

# species.name_lookup(facet='nameType', limit=0)
# species.name_lookup(facet='habitat', limit=0)
# species.name_lookup(facet='datasetKey', limit=0)
# species.name_lookup(facet='rank', limit=0)
# species.name_lookup(facet='isExtinct', limit=0)

# text highlighting
species.name_lookup(q='plant', hl=True, limit=30)

# Lookup by datasetKey
species.name_lookup(datasetKey='3f8a1297-3259-4700-91fc-acc4170b27ce')

# %%
test_data_1 = species.name_lookup(institution_code="iNaturalist", q='Pygoscelis adeliae')
test_data_2 = species.name_lookup(q='Pygoscelis adeliae')
test_data_1 == test_data_2
# Out:
# False

# %%
from pygbif import occurrences as occ

# %%
type(adelie_iNat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 type(adelie_iNat)
#
# NameError: name 'adelie_iNat' is not defined

# %%
adelie_data = occ.search(institutionCode="iNaturalist", sp

# %% [markdown]
# USE CASE:

# %%
### Use Case: Investigating where the most iNaturalist observations are recorded

Much ecological data, including iNaturalist data, is biased towards recording observations where the observers are, not necessarily where the species are. This means that observations don't necessarily refelect the spatial distribution of species.

# %%
test_data_1 = species.name_lookup(institution_code="iNaturalist", q='Pygoscelis adeliae')

# %%
type(test_data_1)

test_data_1
# Out:
# {'offset': 0,
#  'limit': 100,
#  'endOfRecords': True,
#  'count': 42,
#  'results': [{'key': 123208669,
#    'nameKey': 9561924,
#    'datasetKey': 'a5dd063e-f45b-4a54-8b94-8fa3adf7f1e1',
#    'nubKey': 2481663,
#    'parentKey': 167183729,
#    'parent': 'Spheniscidae',
#    'kingdom': 'Animalia',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 167183684,
#    'orderKey': 167183728,
#    'familyKey': 167183729,
#    'speciesKey': 123208669,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adeliepinguin', 'language': 'deu'},
#     {'vernacularName': 'Adeliepingvin', 'language': 'dan'},
#     {'vernacularName': 'Adeliepingvin', 'language': 'nor'},
#     {'vernacularName': 'Adelės Žemės pingvinas', 'language': 'lit'},
#     {'vernacularName': 'Adélie-pingvin', 'language': 'hun'},
#     {'vernacularName': 'Adéliepinguïn', 'language': 'nld'},
#     {'vernacularName': "Manchot d'Adélie", 'language': 'fra'},
#     {'vernacularName': 'Pinguino di Adelia', 'language': 'ita'},
#     {'vernacularName': 'Pingüino de Adelia', 'language': 'spa'},
#     {'vernacularName': 'adeelia pingviin', 'language': 'est'},
#     {'vernacularName': 'adéliepingvin', 'language': 'swe'},
#     {'vernacularName': 'jääpingviini', 'language': 'fin'},
#     {'vernacularName': 'pinguim-de-adélia', 'language': 'por'},
#     {'vernacularName': 'pingwin białooki', 'language': 'pol'},
#     {'vernacularName': "pingüí d'Adèlia", 'language': 'cat'},
#     {'vernacularName': 'tučniak okatý', 'language': 'slk'},
#     {'vernacularName': 'tučňák kroužkový', 'language': 'ces'},
#     {'vernacularName': 'Пингвин Адели', 'language': 'rus'},
#     {'vernacularName': 'アデリーペンギン', 'language': 'jpn'},
#     {'vernacularName': '阿德利企鵝', 'language': 'zho'},
#     {'vernacularName': '阿德利企鹅', 'language': 'zho'}],
#    'synonym': False,
#    'higherClassificationMap': {'167183684': 'Animalia',
#     '167183728': 'Sphenisciformes',
#     '167183729': 'Spheniscidae'}},
#   {'key': 116893181,
#    'nameKey': 9561924,
#    'datasetKey': '71667154-257d-4d8e-a2a5-711aaf9b2d74',
#    'nubKey': 2481663,
#    'parentKey': 116893170,
#    'parent': 'Pygoscelis',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'classKey': 116891945,
#    'orderKey': 116893082,
#    'familyKey': 116893092,
#    'genusKey': 116893170,
#    'speciesKey': 116893181,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie penguin',
#      'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'116891945': 'Aves',
#     '116893082': 'Sphenisciformes',
#     '116893092': 'Spheniscidae',
#     '116893170': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 168018350,
#    'datasetKey': 'a6c6cead-b5ce-4a4e-8cf5-1542ba708dec',
#    'nubKey': 2481663,
#    'parentKey': 168018346,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 167920784,
#    'phylumKey': 168001715,
#    'classKey': 168003099,
#    'orderKey': 168018306,
#    'familyKey': 168018308,
#    'genusKey': 168018346,
#    'speciesKey': 168018350,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'adeliepingvin', 'language': 'nob'}],
#    'synonym': False,
#    'higherClassificationMap': {'167920784': 'Animalia',
#     '168001715': 'Chordata',
#     '168003099': 'Aves',
#     '168018306': 'Sphenisciformes',
#     '168018308': 'Spheniscidae',
#     '168018346': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 100172151,
#    'nameKey': 9561924,
#    'datasetKey': 'd7435f14-dfc9-4aaa-bef3-5d1ed22d65bf',
#    'nubKey': 2481663,
#    'parentKey': 128728038,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 128725468,
#    'classKey': 128725469,
#    'familyKey': 128728032,
#    'genusKey': 128728038,
#    'speciesKey': 100172151,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin',
#      'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'128725468': 'Animalia',
#     '128725469': 'Aves',
#     '128728032': 'Spheniscidae',
#     '128728038': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 133143032,
#    'nameKey': 9561924,
#    'datasetKey': '47f16512-bf31-410f-b272-d151c996b2f6',
#    'nubKey': 2481663,
#    'parentKey': 135274718,
#    'parent': 'Spheniscidae',
#    'kingdom': 'Animalia',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 135274602,
#    'classKey': 135274603,
#    'orderKey': 135274717,
#    'familyKey': 135274718,
#    'speciesKey': 133143032,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'extinct': False,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [{'description': 'Circumpolar Antarctic seas to edge of ice pack'}],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin',
#      'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'135274602': 'Animalia',
#     '135274603': 'Aves',
#     '135274717': 'Sphenisciformes',
#     '135274718': 'Spheniscidae'},
#    'class': 'Aves'},
#   {'key': 104146798,
#    'nameKey': 9561924,
#    'datasetKey': 'fab88965-e69d-4491-a04d-e3198b626e52',
#    'nubKey': 2481663,
#    'parentKey': 104146796,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Metazoa',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 103832354,
#    'phylumKey': 103882489,
#    'classKey': 104106614,
#    'orderKey': 104146736,
#    'familyKey': 104146737,
#    'genusKey': 104146796,
#    'speciesKey': 104146798,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie penguin', 'language': ''}],
#    'synonym': False,
#    'higherClassificationMap': {'103832354': 'Metazoa',
#     '103882489': 'Chordata',
#     '104106614': 'Aves',
#     '104146736': 'Sphenisciformes',
#     '104146737': 'Spheniscidae',
#     '104146796': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 177664922,
#    'datasetKey': '6b6b2923-0a10-4708-b170-5b7c611aceef',
#    'nubKey': 2481663,
#    'parentKey': 177664908,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Metazoa',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 177651702,
#    'phylumKey': 177654008,
#    'classKey': 177656782,
#    'orderKey': 177664856,
#    'familyKey': 177664859,
#    'genusKey': 177664908,
#    'speciesKey': 177664922,
#    'scientificName': 'Pygoscelis adeliae',
#    'canonicalName': 'Pygoscelis adeliae',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'177651702': 'Metazoa',
#     '177654008': 'Chordata',
#     '177656782': 'Aves',
#     '177664856': 'Sphenisciformes',
#     '177664859': 'Spheniscidae',
#     '177664908': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 123516443,
#    'nameKey': 96369396,
#    'datasetKey': 'e01b0cbb-a10a-420c-b5f3-a3b20cc266ad',
#    'nubKey': 10492546,
#    'parentKey': 204866575,
#    'parent': 'Gammapolyomavirus',
#    'kingdom': 'Viruses',
#    'phylum': 'Cossaviricota',
#    'order': 'Sepolyvirales',
#    'family': 'Polyomaviridae',
#    'genus': 'Gammapolyomavirus',
#    'species': 'Pygoscelis adeliae polyomavirus 1',
#    'kingdomKey': 204866491,
#    'phylumKey': 204866541,
#    'classKey': 204866572,
#    'orderKey': 204866573,
#    'familyKey': 204866574,
#    'genusKey': 204866575,
#    'speciesKey': 123516443,
#    'scientificName': 'Pygoscelis adeliae polyomavirus 1',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'204866491': 'Viruses',
#     '204866541': 'Cossaviricota',
#     '204866572': 'Papovaviricetes',
#     '204866573': 'Sepolyvirales',
#     '204866574': 'Polyomaviridae',
#     '204866575': 'Gammapolyomavirus'},
#    'class': 'Papovaviricetes'},
#   {'key': 10492546,
#    'nameKey': 9561933,
#    'datasetKey': 'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c',
#    'constituentKey': '7ddf754f-d193-4cc9-b351-99906754a03b',
#    'parentKey': 10119824,
#    'parent': 'Gammapolyomavirus',
#    'kingdom': 'incertae sedis',
#    'phylum': 'Cossaviricota',
#    'order': 'Sepolyvirales',
#    'family': 'Polyomaviridae',
#    'genus': 'Gammapolyomavirus',
#    'species': 'Pygoscelis adeliae polyomavirus 1',
#    'kingdomKey': 0,
#    'phylumKey': 10738531,
#    'classKey': 10695749,
#    'orderKey': 10819697,
#    'familyKey': 1935,
#    'genusKey': 10119824,
#    'speciesKey': 10492546,
#    'scientificName': 'Pygoscelis adeliae polyomavirus 1',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'extinct': False,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'0': 'incertae sedis',
#     '10738531': 'Cossaviricota',
#     '10695749': 'Papovaviricetes',
#     '10819697': 'Sepolyvirales',
#     '1935': 'Polyomaviridae',
#     '10119824': 'Gammapolyomavirus'},
#    'class': 'Papovaviricetes'},
#   {'key': 167098741,
#    'nameKey': 90764696,
#    'datasetKey': 'fab88965-e69d-4491-a04d-e3198b626e52',
#    'parentKey': 126092220,
#    'parent': 'Treisepsilonpapillomavirus 1',
#    'acceptedKey': 102476485,
#    'accepted': 'Pygoscelis adeliae papillomavirus 1',
#    'kingdom': 'Shotokuvirae',
#    'phylum': 'Cossaviricota',
#    'order': 'Zurhausenvirales',
#    'family': 'Papillomaviridae',
#    'genus': 'Treisepsilonpapillomavirus',
#    'species': 'Treisepsilonpapillomavirus 1',
#    'kingdomKey': 167096094,
#    'phylumKey': 167097670,
#    'classKey': 167098463,
#    'orderKey': 167098464,
#    'familyKey': 102475703,
#    'genusKey': 126092219,
#    'speciesKey': 126092220,
#    'scientificName': 'Pygoscelis adeliae papillomavirus',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'SYNONYM',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': True,
#    'higherClassificationMap': {'167096094': 'Shotokuvirae',
#     '167097670': 'Cossaviricota',
#     '167098463': 'Papovaviricetes',
#     '167098464': 'Zurhausenvirales',
#     '102475703': 'Papillomaviridae',
#     '126092219': 'Treisepsilonpapillomavirus',
#     '126092220': 'Treisepsilonpapillomavirus 1'},
#    'class': 'Papovaviricetes'},
#   {'key': 170811363,
#    'nameKey': 94658221,
#    'datasetKey': '7ddf754f-d193-4cc9-b351-99906754a03b',
#    'constituentKey': '745c2168-a9b8-42e7-8d3e-eed5e7c5f09b',
#    'nubKey': 10492546,
#    'parentKey': 174797086,
#    'parent': 'Gammapolyomavirus',
#    'kingdom': 'Shotokuvirae',
#    'phylum': 'Cossaviricota',
#    'order': 'Sepolyvirales',
#    'family': 'Polyomaviridae',
#    'genus': 'Gammapolyomavirus',
#    'species': 'Pygoscelis adeliae polyomavirus 1',
#    'kingdomKey': 194438846,
#    'phylumKey': 170810361,
#    'classKey': 170810772,
#    'orderKey': 170811233,
#    'familyKey': 174797037,
#    'genusKey': 174797086,
#    'speciesKey': 170811363,
#    'scientificName': 'Pygoscelis adeliae polyomavirus 1',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'extinct': False,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'194438846': 'Shotokuvirae',
#     '170810361': 'Cossaviricota',
#     '170810772': 'Papovaviricetes',
#     '170811233': 'Sepolyvirales',
#     '174797037': 'Polyomaviridae',
#     '174797086': 'Gammapolyomavirus'},
#    'class': 'Papovaviricetes'},
#   {'key': 116786955,
#    'nameKey': 9561926,
#    'datasetKey': '88f4e35a-bdf8-4aa2-9a1b-56401d4eed15',
#    'nubKey': 2481663,
#    'parentKey': 116786943,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Spheniscidae',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 132774790,
#    'phylumKey': 116785007,
#    'classKey': 116785780,
#    'orderKey': 116786923,
#    'familyKey': 116786924,
#    'genusKey': 116786943,
#    'speciesKey': 116786955,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie-Pinguin',
#      'language': 'deu'}],
#    'synonym': False,
#    'higherClassificationMap': {'132774790': 'Animalia',
#     '116785007': 'Chordata',
#     '116785780': 'Aves',
#     '116786923': 'Spheniscidae',
#     '116786924': 'Spheniscidae',
#     '116786943': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 176605938,
#    'nameKey': 9561926,
#    'datasetKey': '19491596-35ae-4a91-9a98-85cf505f1bd3',
#    'parentKey': 203623122,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Aves',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 203622999,
#    'phylumKey': 203623051,
#    'classKey': 203623105,
#    'orderKey': 203623106,
#    'familyKey': 203623107,
#    'genusKey': 203623122,
#    'speciesKey': 176605938,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': ['LEAST_CONCERN'],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adélie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Pingüino adelaida', 'language': 'spa'}],
#    'synonym': False,
#    'higherClassificationMap': {'203622999': 'Animalia',
#     '203623051': 'Chordata',
#     '203623105': 'Sphenisciformes',
#     '203623106': 'Aves',
#     '203623107': 'Spheniscidae',
#     '203623122': 'Pygoscelis'},
#    'class': 'Sphenisciformes'},
#   {'key': 2481663,
#    'nameKey': 9561926,
#    'datasetKey': 'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c',
#    'constituentKey': '7ddf754f-d193-4cc9-b351-99906754a03b',
#    'nubKey': 2481663,
#    'parentKey': 2481662,
#    'parent': 'Pygoscelis',
#    'basionymKey': 5817056,
#    'basionym': 'Catarrhactes adeliae (Hombon & Jacquinot, 1841)',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 212,
#    'orderKey': 7190978,
#    'familyKey': 5284,
#    'genusKey': 2481662,
#    'speciesKey': 2481663,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 1,
#    'numOccurrences': 0,
#    'extinct': False,
#    'habitats': ['MARINE'],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [{'description': 'Circumpolar Antarctic seas to edge of ice pack'},
#     {'description': 'Breeding regions are SO, AN. Breeding subregions are Antarctic coasts and islands. Non breeding regions are to edge of pack-ice.'}],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adelie penguin', 'language': 'eng'},
#     {'vernacularName': 'adeliepingvin', 'language': 'nob'},
#     {'vernacularName': 'Adeliepinguin', 'language': 'deu'},
#     {'vernacularName': 'Adélie penguin', 'language': 'eng'},
#     {'vernacularName': 'Adélie-pinguïn', 'language': 'nld'},
#     {'vernacularName': "Manchot d'Adélie", 'language': 'fra'},
#     {'vernacularName': 'penguen', 'language': 'tur'},
#     {'vernacularName': 'Adelie Penguin', 'language': 'eng'},
#     {'vernacularName': 'Adeliepinguin', 'language': 'deu'},
#     {'vernacularName': 'Adeliepingvin', 'language': 'dan'},
#     {'vernacularName': 'Adeliepingvin', 'language': 'nor'},
#     {'vernacularName': 'Adelės Žemės pingvinas', 'language': 'lit'},
#     {'vernacularName': 'Adélie-pingvin', 'language': 'hun'},
#     {'vernacularName': 'Adéliepinguïn', 'language': 'nld'},
#     {'vernacularName': "Manchot d'Adélie", 'language': 'fra'},
#     {'vernacularName': 'Pinguino di Adelia', 'language': 'ita'},
#     {'vernacularName': 'Pingüino de Adelia', 'language': 'spa'},
#     {'vernacularName': 'adeelia pingviin', 'language': 'est'},
#     {'vernacularName': 'adéliepingvin', 'language': 'swe'},
#     {'vernacularName': 'jääpingviini', 'language': 'fin'},
#     {'vernacularName': 'pinguim-de-adélia', 'language': 'por'},
#     {'vernacularName': 'pingwin białooki', 'language': 'pol'},
#     {'vernacularName': "pingüí d'Adèlia", 'language': 'cat'},
#     {'vernacularName': 'tučniak okatý', 'language': 'slk'},
#     {'vernacularName': 'tučňák kroužkový', 'language': 'ces'},
#     {'vernacularName': 'Пингвин Адели', 'language': 'rus'},
#     {'vernacularName': 'アデリーペンギン', 'language': 'jpn'},
#     {'vernacularName': '阿德利企鵝', 'language': 'zho'},
#     {'vernacularName': '阿德利企鹅', 'language': 'zho'},
#     {'vernacularName': 'Adelie penguin', 'language': 'eng'},
#     {'vernacularName': 'Adelie-Pinguin', 'language': 'deu'},
#     {'vernacularName': 'Adelie penguin', 'language': ''},
#     {'vernacularName': 'Adeliepinguin', 'language': ''},
#     {'vernacularName': 'Adélie penguin', 'language': ''},
#     {'vernacularName': 'Adélie penguin', 'language': 'eng'},
#     {'vernacularName': 'Adélie-pinguïn', 'language': ''},
#     {'vernacularName': "Manchot d'Adélie", 'language': ''},
#     {'vernacularName': 'Penguen', 'language': ''},
#     {'vernacularName': 'Adelie Penguin', 'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'1': 'Animalia',
#     '44': 'Chordata',
#     '212': 'Aves',
#     '7190978': 'Sphenisciformes',
#     '5284': 'Spheniscidae',
#     '2481662': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 155307901,
#    'nameKey': 9561926,
#    'datasetKey': '2d59e5db-57ad-41ff-97d6-11f5fb264527',
#    'nubKey': 2481663,
#    'parentKey': 155307892,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 154946057,
#    'phylumKey': 155295572,
#    'classKey': 155304455,
#    'orderKey': 155307869,
#    'familyKey': 155307873,
#    'genusKey': 155307892,
#    'speciesKey': 155307901,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': ['MARINE'],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adeliepinguin', 'language': 'deu'},
#     {'vernacularName': 'Adélie penguin', 'language': 'eng'},
#     {'vernacularName': 'Adélie-pinguïn', 'language': 'nld'},
#     {'vernacularName': "Manchot d'Adélie", 'language': 'fra'},
#     {'vernacularName': 'penguen', 'language': 'tur'}],
#    'synonym': False,
#    'higherClassificationMap': {'154946057': 'Animalia',
#     '155295572': 'Chordata',
#     '155304455': 'Aves',
#     '155307869': 'Sphenisciformes',
#     '155307873': 'Spheniscidae',
#     '155307892': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 165902931,
#    'nameKey': 9561926,
#    'datasetKey': 'c696e5ee-9088-4d11-bdae-ab88daffab78',
#    'nubKey': 2481663,
#    'parentKey': 165902933,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 100217010,
#    'classKey': 100217014,
#    'orderKey': 165902937,
#    'familyKey': 165902936,
#    'genusKey': 165902933,
#    'speciesKey': 165902931,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [{'description': 'Breeding regions are SO, AN. Breeding subregions are Antarctic coasts and islands. Non breeding regions are to edge of pack-ice.'}],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin',
#      'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'100217010': 'Animalia',
#     '100217014': 'Aves',
#     '165902937': 'Sphenisciformes',
#     '165902936': 'Spheniscidae',
#     '165902933': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 100528965,
#    'nameKey': 9561926,
#    'datasetKey': '16c3f9cb-4b19-4553-ac8e-ebb90003aa02',
#    'nubKey': 2481663,
#    'parentKey': 203605762,
#    'parent': 'Pygoscelis',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'classKey': 100347857,
#    'orderKey': 203605752,
#    'familyKey': 203605756,
#    'genusKey': 203605762,
#    'speciesKey': 100528965,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions':
zur Westküste der Antarktischen Halbinsel, entlang Inseln der Scotiasee bis zu den Südlichen Sandwichinseln. Das Verbreitungsgebiet nichtbrütender Vögel ist nicht sehr gut erforscht. Vermutlich wandern sie nicht weiter als bis zum Rand der Packeisgrenze. Irrgäste werden gelegentlich an der südamerikanischen, australischen und neuseeländischen Küste beobachtet. Sie tauchen außerdem an subarktischen Inseln des Indischen und Pazifischen Ozeans auf. Die größte Brutkolonie befindet sich auf Kap Adare. Dort brüten etwa 282.307 Brutpaare.'}],
#    'vernacularNames': [{'vernacularName': 'Adeliepinguin', 'language': 'deu'}],
#    'synonym': False,
#    'higherClassificationMap': {'100347857': 'Aves',
#     '203605752': 'Sphenisciformes',
#     '203605756': 'Spheniscidae',
#     '203605762': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 172747280,
#    'nameKey': 9561926,
#    'datasetKey': '7ddf754f-d193-4cc9-b351-99906754a03b',
#    'constituentKey': 'c2508dd9-c6dc-4312-879b-2b80d23dc6c1',
#    'nubKey': 2481663,
#    'parentKey': 172747268,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 172331902,
#    'phylumKey': 172636724,
#    'classKey': 171152611,
#    'orderKey': 172747245,
#    'familyKey': 172747247,
#    'genusKey': 172747268,
#    'speciesKey': 172747280,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'extinct': False,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin',
#      'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'172331902': 'Animalia',
#     '172636724': 'Chordata',
#     '171152611': 'Aves',
#     '172747245': 'Sphenisciformes',
#     '172747247': 'Spheniscidae',
#     '172747268': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 102476485,
#    'nameKey': 90764692,
#    'datasetKey': 'fab88965-e69d-4491-a04d-e3198b626e52',
#    'parentKey': 126092220,
#    'parent': 'Treisepsilonpapillomavirus 1',
#    'kingdom': 'Shotokuvirae',
#    'phylum': 'Cossaviricota',
#    'order': 'Zurhausenvirales',
#    'family': 'Papillomaviridae',
#    'genus': 'Treisepsilonpapillomavirus',
#    'species': 'Treisepsilonpapillomavirus 1',
#    'kingdomKey': 167096094,
#    'phylumKey': 167097670,
#    'classKey': 167098463,
#    'orderKey': 167098464,
#    'familyKey': 102475703,
#    'genusKey': 126092219,
#    'speciesKey': 126092220,
#    'scientificName': 'Pygoscelis adeliae papillomavirus 1',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SEROVAR',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'167096094': 'Shotokuvirae',
#     '167097670': 'Cossaviricota',
#     '167098463': 'Papovaviricetes',
#     '167098464': 'Zurhausenvirales',
#     '102475703': 'Papillomaviridae',
#     '126092219': 'Treisepsilonpapillomavirus',
#     '126092220': 'Treisepsilonpapillomavirus 1'},
#    'class': 'Papovaviricetes'},
#   {'key': 179692531,
#    'nameKey': 96695237,
#    'datasetKey': '6b6b2923-0a10-4708-b170-5b7c611aceef',
#    'parentKey': 179692525,
#    'parent': 'Treisepsilonpapillomavirus 1',
#    'kingdom': 'Shotokuvirae',
#    'phylum': 'Cossaviricota',
#    'order': 'Zurhausenvirales',
#    'family': 'Papillomaviridae',
#    'genus': 'Treisepsilonpapillomavirus',
#    'species': 'Treisepsilonpapillomavirus 1',
#    'kingdomKey': 179677050,
#    'phylumKey': 179686601,
#    'classKey': 179689417,
#    'orderKey': 179690509,
#    'familyKey': 179690512,
#    'genusKey': 179692522,
#    'speciesKey': 179692525,
#    'scientificName': 'Pygoscelis adeliae papillomavirus 1',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'ACCEPTED',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'179677050': 'Shotokuvirae',
#     '179686601': 'Cossaviricota',
#     '179689417': 'Papovaviricetes',
#     '179690509': 'Zurhausenvirales',
#     '179690512': 'Papillomaviridae',
#     '179692522': 'Treisepsilonpapillomavirus',
#     '179692525': 'Treisepsilonpapillomavirus 1'},
#    'class': 'Papovaviricetes'},
#   {'key': 179692528,
#    'nameKey': 96695236,
#    'datasetKey': '6b6b2923-0a10-4708-b170-5b7c611aceef',
#    'parentKey': 179692525,
#    'parent': 'Treisepsilonpapillomavirus 1',
#    'kingdom': 'Shotokuvirae',
#    'phylum': 'Cossaviricota',
#    'order': 'Zurhausenvirales',
#    'family': 'Papillomaviridae',
#    'genus': 'Treisepsilonpapillomavirus',
#    'species': 'Treisepsilonpapillomavirus 1',
#    'kingdomKey': 179677050,
#    'phylumKey': 179686601,
#    'classKey': 179689417,
#    'orderKey': 179690509,
#    'familyKey': 179690512,
#    'genusKey': 179692522,
#    'speciesKey': 179692525,
#    'scientificName': 'Pygoscelis adeliae papillomavirus 2',
#    'authorship': '',
#    'nameType': 'VIRUS',
#    'taxonomicStatus': 'ACCEPTED',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'179677050': 'Shotokuvirae',
#     '179686601': 'Cossaviricota',
#     '179689417': 'Papovaviricetes',
#     '179690509': 'Zurhausenvirales',
#     '179690512': 'Papillomaviridae',
#     '179692522': 'Treisepsilonpapillomavirus',
#     '179692525': 'Treisepsilonpapillomavirus 1'},
#    'class': 'Papovaviricetes'},
#   {'key': 185017917,
#    'nameKey': 56347404,
#    'datasetKey': 'c33ce2f2-c3cc-43a5-a380-fe4526d63650',
#    'nubKey': 2481663,
#    'parentKey': 121514500,
#    'parent': 'Pygoscelis',
#    'acceptedKey': 185017916,
#    'accepted': 'Catarrhactes adeliae (Hombon & Jacquinot, 1841)',
#    'basionymKey': 185017916,
#    'basionym': 'Catarrhactes adeliae (Hombon & Jacquinot, 1841)',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Catarrhactes adeliae',
#    'phylumKey': 121445866,
#    'classKey': 121497163,
#    'orderKey': 121514275,
#    'familyKey': 121514426,
#    'genusKey': 121514500,
#    'speciesKey': 185017916,
#    'scientificName': 'Pygoscelis adeliae (Hombon & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombon & Jacquinot, 1841) ',
#    'accordingTo': 'accretion,modification of parts',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'SYNONYM',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'extinct': False,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie penguin',
#      'language': 'eng'}],
#    'synonym': True,
#    'higherClassificationMap': {'121445866': 'Chordata',
#     '121497163': 'Aves',
#     '121514275': 'Sphenisciformes',
#     '121514426': 'Spheniscidae',
#     '121514500': 'Pygoscelis',
#     '185017916': 'Catarrhactes adeliae'},
#    'class': 'Aves'},
#   {'key': 102110362,
#    'nameKey': 9561926,
#    'datasetKey': '9ca92552-f23a-41a8-a140-01abaa31c931',
#    'nubKey': 2481663,
#    'parentKey': 102110361,
#    'parent': 'Pygoscelis',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 101683523,
#    'phylumKey': 102017110,
#    'classKey': 102085317,
#    'orderKey': 102110331,
#    'familyKey': 102110332,
#    'genusKey': 102110361,
#    'speciesKey': 102110362,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [{'vernacularName': 'Adelie Penguin',
#      'language': 'eng'}],
#    'synonym': False,
#    'higherClassificationMap': {'101683523': 'Animalia',
#     '102017110': 'Chordata',
#     '102085317': 'Aves',
#     '102110331': 'Sphenisciformes',
#     '102110332': 'Spheniscidae',
#     '102110361': 'Pygoscelis'},
#    'class': 'Aves'},
#   {'key': 113269385,
#    'nameKey': 9561926,
#    'datasetKey': 'cbb6498e-8927-405a-916b-576d00a6289b',
#    'nubKey': 2481663,
#    'parentKey': 144105141,
#    'parent': 'Pygoscelis',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'genusKey': 144105141,
#    'speciesKey': 113269385,
#    'scientificName': 'Pygoscelis adeliae (Hombron & Jacquinot, 1841)',
#    'canonicalName': 'Pygoscelis adeliae',
#    'authorship': '(Hombron & Jacquinot, 1841) ',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [{'description': "The Adélie penguin (Pygoscelis adeliae) is a species of penguin common along the entire coast of the Antarctic continent, which is the only place where it is found. It is the most widespread penguin species, and, along with the emperor penguin, is the most southerly distributed of all penguins. It is named after Adélie Land, in turn named for Adèle Dumont d'Urville, who was married to French explorer Jules Dumont d'Urville, who first discovered this penguin in 1840. Adélie penguins obtain their food by both predation and foraging, with a diet of mainly krill and fish."},
# ...
#     {'description': 'Am 25. April wird international der Weltpinguintag begangen.'},
r variabel und recht unabhängig von der Jahreszeit. Zwergpinguine und die Jungen der Brillenpinguine sehen sich sehr ähnlich, ein Befund, der als Hinweis auf die enge Verwandtschaft der beiden Gattungen gewertet wird. Die verwandtschaftlichen Beziehungen der Gattungen und Arten zueinander kommen in dem folgenden Kladogramm zum Ausdruck, das auf der Analyse des Genoms aller Pinguinarten beruht:Hailin Pan et al. 2019. High-coverage genomes to elucidate the evolution of penguins. GigaScience 8 (9): giz117; doi:10.1093/gigascience/giz117 Schnellübersicht nach Gattungen Angegeben sind auch der Lebensraum und die äußeren Merkmale Langschwanzpinguine, Antarktis, schwarz-weiß gefiedert Eselspinguin, subantarktische Inseln/Antarktische Halbinsel Adeliepinguin, Antarktis Zügelpinguin, Kehlstreifpinguin, Antarktische Halbinsel Großpinguine, Antarktis, größte Pinguine Königspinguin, subantarktische Inseln Kaiserpinguin, Antarktis Schopfpinguine, Australien/Neuseeland, gelb-orangefarbener Federschmuck am Kopf Dickschnabelpinguin, Australien/Neuseeland Snaresinselpinguin, Snaresinseln Kronenpinguin, Sclater-Pinguin, Australien/Neuseeland Haubenpinguin, subantarktische Inseln Goldschopfpinguin Felsenpinguin, subantarktische Inseln Tristanpinguin, südlicher Atlantik Gelbaugenpinguine, Australi ...
#     {'description': 'Pinguine leben in den offenen Meeren der südlichen Hemisphäre. Dort finden sie sich insbesondere in den Küstengewässern der Antarktis, in Neuseeland, dem südlichen Australien, Südafrika, Namibia (Pinguin-Inseln), südliches Angola, auf den vor Südamerika gelegenen Falklandinseln und an der Westküste hinauf bis nach Peru sowie auf den am Äquator gelegenen Galápagos-Inseln. Als kälteliebende Vögel treten sie in tropischen Gebieten nur dann auf, wenn Kaltwasserströmungen existieren; dies ist etwa an der Westküste Südamerikas mit dem Humboldt-Strom oder um Südafrika mit dem Benguela-Strom an der Kap-Halbinsel der Fall. Die meisten Arten leben etwa zwischen dem 45. und dem 60. Breitengrad südlicher Breite; die größte Individuenzahl findet sich um die Antarktis und auf nahegelegenen Inseln. Auf der Nordhalbkugel leben mit Ausnahme von Zootieren und eines Teils der Population des Galápagos-Pinguins auf der auf Äquatorhöhe gelegenen Galápagos-Insel Isabela keine Pinguine.'}],
#    'vernacularNames': [{'vernacularName': '10.1038/nature15697',
#      'language': ''},
#     {'vernacularName': 'Pinguine', 'language': 'deu'}],
#    'synonym': False,
#    'higherClassificationMap': {'100347857': 'Aves',
#     '203605752': 'Sphenisciformes'},
#    'class': 'Aves'},
#   {'key': 158185422,
#    'nameKey': 94556265,
#    'datasetKey': '4cec8fef-f129-4966-89b7-4f8439aba058',
#    'parentKey': 158185420,
#    'parent': 'Pygoscelis adeliae',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 157533281,
#    'phylumKey': 158135805,
#    'classKey': 158183130,
#    'orderKey': 158185404,
#    'familyKey': 158185406,
#    'genusKey': 158185408,
#    'speciesKey': 158185420,
#    'scientificName': 'BOLD:AAB8138',
#    'authorship': '',
#    'nameType': 'OTU',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'UNRANKED',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'157533281': 'Animalia',
#     '158135805': 'Chordata',
#     '158183130': 'Aves',
#     '158185404': 'Sphenisciformes',
#     '158185406': 'Spheniscidae',
#     '158185408': 'Pygoscelis',
#     '158185420': 'Pygoscelis adeliae'},
#    'class': 'Aves'},
#   {'key': 9958364,
#    'nameKey': 30402930,
#    'datasetKey': 'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c',
#    'constituentKey': '4cec8fef-f129-4966-89b7-4f8439aba058',
#    'parentKey': 2481663,
#    'parent': 'Pygoscelis adeliae',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 212,
#    'orderKey': 7190978,
#    'familyKey': 5284,
#    'genusKey': 2481662,
#    'speciesKey': 2481663,
#    'scientificName': 'BOLD:AAB8138',
#    'authorship': '',
#    'nameType': 'OTU',
#    'taxonomicStatus': 'ACCEPTED',
#    'rank': 'UNRANKED',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': False,
#    'higherClassificationMap': {'1': 'Animalia',
#     '44': 'Chordata',
#     '212': 'Aves',
#     '7190978': 'Sphenisciformes',
#     '5284': 'Spheniscidae',
#     '2481662': 'Pygoscelis',
#     '2481663': 'Pygoscelis adeliae'},
#    'class': 'Aves'},
#   {'key': 166359797,
#    'nameKey': 9561922,
#    'datasetKey': 'fab88965-e69d-4491-a04d-e3198b626e52',
#    'parentKey': 104146796,
#    'parent': 'Pygoscelis',
#    'acceptedKey': 104146798,
#    'accepted': 'Pygoscelis adeliae',
#    'kingdom': 'Metazoa',
#    'phylum': 'Chordata',
#    'order': 'Sphenisciformes',
#    'family': 'Spheniscidae',
#    'genus': 'Pygoscelis',
#    'species': 'Pygoscelis adeliae',
#    'kingdomKey': 103832354,
#    'phylumKey': 103882489,
#    'classKey': 104106614,
#    'orderKey': 104146736,
#    'familyKey': 104146737,
#    'genusKey': 104146796,
#    'speciesKey': 104146798,
#    'scientificName': 'Pygoscelis adelia',
#    'canonicalName': 'Pygoscelis adelia',
#    'authorship': '',
#    'nameType': 'SCIENTIFIC',
#    'taxonomicStatus': 'SYNONYM',
#    'origin': 'SOURCE',
#    'numDescendants': 0,
#    'numOccurrences': 0,
#    'habitats': [],
#    'nomenclaturalStatus': [],
#    'threatStatuses': [],
#    'descriptions': [],
#    'vernacularNames': [],
#    'synonym': True,
#    'higherClassificationMap': {'103832354': 'Metazoa',
#     '103882489': 'Chordata',
#     '104106614': 'Aves',
#     '104146736': 'Sphenisciformes',
#     '104146737': 'Spheniscidae',
#     '104146796': 'Pygoscelis',
#     '104146798': 'Pygoscelis adeliae'},
#    'class': 'Aves'}],
#  'facets': []}

# %%
df = pd.DataFrame.from_dict(test_data_1, orient='index') #THIS WORKED!

# test_DF.from_dict(test_data_1, orient='columns')

# %%
df.head()
# Out:
#                                                               0
# offset                                                        0
# limit                                                       100
# endOfRecords                                               True
# count                                                        42
# results       [{'key': 123208669, 'nameKey': 9561924, 'datas...

# %%
adelie_iNat = occ.search(institutionCode="iNaturalist", limit=20, )

a
