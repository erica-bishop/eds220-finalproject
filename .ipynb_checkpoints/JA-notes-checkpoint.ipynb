# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from zipfile import ZipFile
import cartopy
import cartopy.crs as ccrs
import geopandas as gpd
import shapely

# %%
sb_inat = pd.read_csv("/courses/EDS214/EDS220_gbffs/inat_sb_recent.csv", sep = '\t') #make sure to update the file path to where your data is stored

# %%
tarantulas = sb_inat.loc[sb_inat['family'] == "Theraphosidae"]

# %%
list(tarantulas.columns)
# Out:
# ['gbifID',
#  'datasetKey',
#  'occurrenceID',
#  'kingdom',
#  'phylum',
#  'class',
#  'order',
#  'family',
#  'genus',
#  'species',
#  'infraspecificEpithet',
#  'taxonRank',
#  'scientificName',
#  'verbatimScientificName',
#  'verbatimScientificNameAuthorship',
#  'countryCode',
#  'locality',
#  'stateProvince',
#  'occurrenceStatus',
#  'individualCount',
#  'publishingOrgKey',
#  'decimalLatitude',
#  'decimalLongitude',
#  'coordinateUncertaintyInMeters',
#  'coordinatePrecision',
#  'elevation',
#  'elevationAccuracy',
#  'depth',
#  'depthAccuracy',
#  'eventDate',
#  'day',
#  'month',
#  'year',
#  'taxonKey',
#  'speciesKey',
#  'basisOfRecord',
#  'institutionCode',
#  'collectionCode',
#  'catalogNumber',
#  'recordNumber',
#  'identifiedBy',
#  'dateIdentified',
#  'license',
#  'rightsHolder',
#  'recordedBy',
#  'typeStatus',
#  'establishmentMeans',
#  'lastInterpreted',
#  'mediaType',
#  'issue',
#  'geometry']

# %%
tarantulas.dtypes
# Out:
# gbifID                                 int64
# datasetKey                            object
# occurrenceID                          object
# kingdom                               object
# phylum                                object
# class                                 object
# order                                 object
# family                                object
# genus                                 object
# species                               object
# infraspecificEpithet                  object
# taxonRank                             object
# scientificName                        object
# verbatimScientificName                object
# verbatimScientificNameAuthorship     float64
# countryCode                           object
# locality                             float64
# stateProvince                         object
# occurrenceStatus                      object
# individualCount                      float64
# publishingOrgKey                      object
# decimalLatitude                      float64
# decimalLongitude                     float64
# coordinateUncertaintyInMeters        float64
# coordinatePrecision                  float64
# elevation                            float64
# elevationAccuracy                    float64
# depth                                float64
# depthAccuracy                        float64
# eventDate                             object
# day                                    int64
# month                                  int64
# year                                   int64
# taxonKey                               int64
# speciesKey                           float64
# basisOfRecord                         object
# institutionCode                       object
# collectionCode                        object
# catalogNumber                          int64
# recordNumber                         float64
# identifiedBy                          object
# dateIdentified                        object
# license                               object
# rightsHolder                          object
# recordedBy                            object
# typeStatus                           float64
# establishmentMeans                   float64
# lastInterpreted                       object
# mediaType                             object
# issue                                 object
# geometry                            geometry
# dtype: object

# %%
# Create geometries from your lat-lons
geom_list = [shapely.geometry.Point(lon,lat) for lon,lat in zip(tarantulas["decimalLongitude"] , tarantulas["decimalLatitude"])] # check the ordering of lon/lat

# create geopandas geodataframe
tarantulas_gdf = gpd.GeoDataFrame(tarantulas, geometry=geom_list, crs={"init":"EPSG:4326"})
# Out:
# /opt/python/3.10.5/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
tarantulas_gdf.crs # it's in degrees, we want it in meters! we should reproject it
# Out:
# <Geographic 2D CRS: +init=epsg:4326 +type=crs>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
tarantulas_rpj = tarantulas_gdf.to_crs("EPSG:6423") # NAD83 California Zone 5-- includes SB

tarantulas_rpj.crs # now the unit of measurement is in meters!
# Out:
# <Derived Projected CRS: EPSG:6423>
# Name: NAD83(2011) / California zone 5
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - California - counties Kern; Los Angeles; San Bernardino; San Luis Obispo; Santa Barbara; Ventura.
# - bounds: (-121.42, 32.76, -114.12, 35.81)
# Coordinate Operation:
# - name: SPCS83 California zone 5 (meters)
# - method: Lambert Conic Conformal (2SP)
# Datum: NAD83 (National Spatial Reference System 2011)
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
ucsb_df = pd.DataFrame(
    {'Location': ['Bren Hall'],
     'Latitude': [34.413059],
     'Longitude': [-119.841826]})

ucsb_gdf = gpd.GeoDataFrame(
    ucsb_df, geometry=gpd.points_from_xy(ucsb_df.Longitude, ucsb_df.Latitude))

ucsb_gdf = ucsb_gdf.set_crs('EPSG:6423')

ucsb_buffer = ucsb_gdf.buffer(1610)

friendly_neighbors = tarantulas_rpj["geometry"].intersection(ucsb_buffer)
# Out:
# /opt/python/3.10.5/lib/python3.10/site-packages/geopandas/base.py:31: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")

# %%
nearby_tarantulas = tarantulas_rpj[~friendly_neighbors.is_empty]

len(nearby_tarantulas) # 53 tarantulas have been reported within 1 mile of UCSB since 2008

nearby_tarantulas
# Out:
# /opt/python/3.10.5/lib/python3.10/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
#             gbifID                            datasetKey  \
# 2201    1898831738  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 7013    2563466165  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 10105   2294451477  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 10215   2423071640  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 11666   2826483417  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 13170   2445037736  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 13965   2563472519  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 15564   2898321022  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 17353   2350387486  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 18116   3335121543  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 21552   2868187641  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 23709   2350389502  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 30982   2963857931  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 32114   3747182896  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 47626   3108985366  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 51240   2573835426  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 55444   2423254234  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 59498   2850936096  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 62806   2429540641  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 67771   2563434779  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 68075   1993774683  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 68931   2422915116  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 69564   2563658942  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 73228   3902868754  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 73589   2883102796  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 76180   2283010401  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 77424   2429340235  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 87959   1899798171  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 88021   3759863447  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 91075   1677314967  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 91482   2901612318  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 92300   1932339387  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 93191   2445121716  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 95176   2451701712  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 97508   2850576684  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 101186  1899775478  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 101272  3399221468  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 101719  2423253888  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 103400  2563428938  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 107116  1677301127  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 111392  2563433464  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 117538  2444991867  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 119158  2850897341  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 122706  2422831086  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 125532  1702474716  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 125628  2898418351  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 126228  1677293239  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 129818  3925512518  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 134137  2826522939  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 135522  2851011537  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 135711  2641413418  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 137610  2868198792  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 141418  2563434890  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                              occurrenceID   kingdom  \
# 2201    https://www.inaturalist.org/observations/15782961  Animalia
# 7013    https://www.inaturalist.org/observations/33991504  Animalia
# 10105   https://www.inaturalist.org/observations/28654164  Animalia
# 10215   https://www.inaturalist.org/observations/32731888  Animalia
# 11666   https://www.inaturalist.org/observations/54586761  Animalia
# 13170   https://www.inaturalist.org/observations/34541639  Animalia
# 13965   https://www.inaturalist.org/observations/35937770  Animalia
# 15564   https://www.inaturalist.org/observations/62418607  Animalia
# 17353   https://www.inaturalist.org/observations/30655276  Animalia
# 18116   https://www.inaturalist.org/observations/88076440  Animalia
# 21552   https://www.inaturalist.org/observations/59920545  Animalia
# 101272  Aphonopelma steindachneri  ...  2021-10-19T02:58:59  CC_BY_NC_4_0
# 101719         Aphonopelma iodius  ...  2017-05-21T06:32:52  CC_BY_NC_4_0
# 103400         Aphonopelma iodius  ...  2018-04-16T20:50:34  CC_BY_NC_4_0
# 107116         Aphonopelma iodius  ...  2017-10-15T01:22:39  CC_BY_NC_4_0
# 111392         Aphonopelma iodius  ...  2018-09-11T10:35:41       CC0_1_0
# 117538         Aphonopelma iodius  ...  2019-10-23T02:34:52  CC_BY_NC_4_0
# 119158  Aphonopelma steindachneri  ...  2020-08-12T04:47:52  CC_BY_NC_4_0
# 122706         Aphonopelma iodius  ...  2017-05-21T06:32:07  CC_BY_NC_4_0
# 125532         Aphonopelma iodius  ...  2017-11-06T05:24:32  CC_BY_NC_4_0
# 125628         Aphonopelma iodius  ...  2019-11-11T18:13:13  CC_BY_NC_4_0
# 126228         Aphonopelma iodius  ...  2017-10-14T14:57:03  CC_BY_NC_4_0
# 129818  Aphonopelma steindachneri  ...  2022-10-10T01:16:29  CC_BY_NC_4_0
# 134137  Aphonopelma steindachneri  ...  2020-07-31T15:24:38  CC_BY_NC_4_0
# 135522         Aphonopelma iodius  ...  2020-06-14T11:42:06  CC_BY_NC_4_0
# 135711      Aphonopelma eutylenum  ...  2020-04-18T02:17:05  CC_BY_NC_4_0
# 137610      Aphonopelma eutylenum  ...  2020-09-24T16:55:57  CC_BY_NC_4_0
# 141418         Aphonopelma iodius  ...  2018-11-07T17:29:51  CC_BY_NC_4_0
#
#                     rightsHolder                recordedBy  typeStatus  \
# 2201                    djparisi                  djparisi         NaN
# 7013                     oasaleh                   oasaleh         NaN
# 10105                    Paul G.                   Paul G.         NaN
# 10215                Rachel Behm               Rachel Behm         NaN
# 11666            Pamella Passaro           Pamella Passaro         NaN
# 13170               Jeff Goddard              Jeff Goddard         NaN
# 13965                susantuttle               susantuttle         NaN
# 15564                      ljefe                     ljefe         NaN
# 17353            kathleen_hughes           kathleen_hughes         NaN
# 18116                   laika14a                  laika14a         NaN
# 21552              William Mason             William Mason         NaN
# 23709                    Paul G.                   Paul G.         NaN
# 30982                    zachkin                   zachkin         NaN
# 32114                  top_quark                 top_quark         NaN
# 47626     Tyanna Schlom Blaschak    Tyanna Schlom Blaschak         NaN
# 51240           plants_bugs_dirt          plants_bugs_dirt         NaN
# 55444                    margele                   margele         NaN
# 59498                    Heather                   Heather         NaN
# 62806                    Paul G.                   Paul G.         NaN
# 67771                 QuestaGame                QuestaGame         NaN
# 68075                jijacobs355               jijacobs355         NaN
# 68931                    Paul G.                   Paul G.         NaN
# 69564             maryleehopkins            maryleehopkins         NaN
# 73228                    L Emard                   L Emard         NaN
# 73589                    Paul G.                   Paul G.         NaN
# 76180                   shandrat                  shandrat         NaN
# 77424                lblacquiere               lblacquiere         NaN
# 87959                    roz1412                   roz1412         NaN
# 88021                ruanemartin               ruanemartin         NaN
# 91075                      Debra                     Debra         NaN
# 91482                   mackids2                  mackids2         NaN
# 92300              Leif Behrmann             Leif Behrmann         NaN
# 93191                     goodie                    goodie         NaN
# 95176                    theclam                   theclam         NaN
# 97508         chris_charlesworth        chris_charlesworth         NaN
# 101186             Francis Joyce             Francis Joyce         NaN
# 101272               Max Roberts               Max Roberts         NaN
# 101719  Sedgwick Natural Reserve  Sedgwick Natural Reserve         NaN
# 103400             Francis Joyce             Francis Joyce         NaN
# 107116           samanthaddgreen           samanthaddgreen         NaN
# 111392       Andy Kleinhesselink       Andy Kleinhesselink         NaN
# 117538                  jpylipow                  jpylipow         NaN
# 119158                   Paul G.                   Paul G.         NaN
# 122706              Daniel Keddy              Daniel Keddy         NaN
# 125532                     Debra                     Debra         NaN
# 125628               Alayna Mead               Alayna Mead         NaN
# 126228           samanthaddgreen           samanthaddgreen         NaN
# 129818                     Jacob                     Jacob         NaN
# 134137                  djparisi                  djparisi         NaN
# 135522            Patrick Crooks            Patrick Crooks         NaN
# 135711                   raypows                   raypows         NaN
# 137610                   Paul G.                   Paul G.         NaN
# 141418              Michelle Gee              Michelle Gee         NaN
#
#        establishmentMeans           lastInterpreted  \
# 2201                  NaN  2022-11-11T17:35:19.792Z
# 7013                  NaN  2022-11-11T17:32:13.501Z
# 10105                 NaN  2022-11-11T17:32:04.720Z
# 10215                 NaN  2022-11-11T17:32:07.187Z
# 11666                 NaN  2022-11-11T17:36:15.298Z
# 13170                 NaN  2022-11-11T17:35:30.788Z
# 13965                 NaN  2022-11-11T17:35:38.527Z
# 15564                 NaN  2022-11-11T17:33:07.528Z
# 17353                 NaN  2022-11-11T17:32:04.765Z
# 18116                 NaN  2022-11-11T17:33:56.618Z
# 21552                 NaN  2022-11-11T17:33:11.471Z
# 23709                 NaN  2022-11-11T17:35:29.624Z
# 30982                 NaN  2022-11-11T17:36:44.779Z
# 32114                 NaN  2022-11-11T17:38:06.323Z
# 47626                 NaN  2022-11-11T17:32:33.885Z
# 51240                 NaN  2022-11-11T17:32:17.970Z
# 55444                 NaN  2022-11-11T17:30:58.592Z
# 59498                 NaN  2022-11-11T17:36:07.096Z
# 62806                 NaN  2022-11-11T17:35:37.363Z
# 67771                 NaN  2022-11-11T17:35:18.655Z
# 68075                 NaN  2022-11-11T17:31:10.701Z
# 68931                 NaN  2022-11-11T17:32:06.095Z
# 69564                 NaN  2022-11-11T17:31:18.710Z
# 73228                 NaN  2022-11-11T17:34:48.240Z
# 73589                 NaN  2022-11-11T17:33:09.929Z
# 76180                 NaN  2022-11-11T17:31:53.157Z
# 77424                 NaN  2022-11-11T17:32:13.264Z
# 87959                 NaN  2022-11-11T17:31:42.869Z
# 88021                 NaN  2022-11-11T17:32:37.744Z
# 91075                 NaN  2022-11-11T17:31:27.636Z
# 91482                 NaN  2022-11-11T17:35:23.110Z
# 92300                 NaN  2022-11-11T17:31:43.375Z
# 93191                 NaN  2022-11-11T17:36:03.288Z
# 95176                 NaN  2022-11-11T17:32:14.087Z
# 97508                 NaN  2022-11-11T17:36:06.800Z
# 101186                NaN  2022-11-11T17:35:14.476Z
# 101272                NaN  2022-11-11T17:34:12.539Z
# 101719                NaN  2022-11-11T17:35:06.344Z
# 103400                NaN  2022-11-11T17:35:18.739Z
# 107116                NaN  2022-11-11T17:31:27.291Z
# 111392                NaN  2022-11-11T17:35:18.771Z
# 117538                NaN  2022-11-11T17:35:43.421Z
# 119158                NaN  2022-11-11T17:36:06.621Z
# 122706                NaN  2022-11-11T17:31:07.906Z
# 125532                NaN  2022-11-11T17:31:27.280Z
# 125628                NaN  2022-11-11T17:32:16.864Z
# 126228                NaN  2022-11-11T17:35:29.732Z
# 129818                NaN  2022-11-11T17:34:51.800Z
# 134137                NaN  2022-11-11T17:32:48.237Z
# 135522                NaN  2022-11-11T17:32:27.857Z
# 135711                NaN  2022-11-11T17:32:21.645Z
# 137610                NaN  2022-11-11T17:36:28.551Z
# 141418                NaN  2022-11-11T17:35:20.603Z
#
#                                           mediaType               issue  \
# 2201                                     StillImage  COORDINATE_ROUNDED
# 7013    StillImage;StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 10105                         StillImage;StillImage  COORDINATE_ROUNDED
# 10215                                    StillImage                 NaN
# 11666                                    StillImage  COORDINATE_ROUNDED
# 13170                         StillImage;StillImage  COORDINATE_ROUNDED
# 13965                                    StillImage  COORDINATE_ROUNDED
# 15564              StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 17353   StillImage;StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 18116                                    StillImage  COORDINATE_ROUNDED
# 21552              StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 23709                         StillImage;StillImage  COORDINATE_ROUNDED
# 30982                                    StillImage                 NaN
# 32114                                    StillImage  COORDINATE_ROUNDED
# 47626                                    StillImage  COORDINATE_ROUNDED
# 51240              StillImage;StillImage;StillImage                 NaN
# 55444                                    StillImage  COORDINATE_ROUNDED
# 59498                                    StillImage  COORDINATE_ROUNDED
# 62806                         StillImage;StillImage  COORDINATE_ROUNDED
# 67771                         StillImage;StillImage  COORDINATE_ROUNDED
# 68075                                    StillImage  COORDINATE_ROUNDED
# 68931                         StillImage;StillImage  COORDINATE_ROUNDED
# 69564                                    StillImage  COORDINATE_ROUNDED
# 73228   StillImage;StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 73589                         StillImage;StillImage  COORDINATE_ROUNDED
# 76180                                    StillImage  COORDINATE_ROUNDED
# 77424                         StillImage;StillImage  COORDINATE_ROUNDED
# 87959                                    StillImage  COORDINATE_ROUNDED
# 88021                                    StillImage  COORDINATE_ROUNDED
# 91075                                    StillImage  COORDINATE_ROUNDED
# 91482                                    StillImage  COORDINATE_ROUNDED
# 92300              StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 93191                                    StillImage  COORDINATE_ROUNDED
# 95176                                    StillImage  COORDINATE_ROUNDED
# 97508                                    StillImage  COORDINATE_ROUNDED
# 101186                                   StillImage  COORDINATE_ROUNDED
# 101272                        StillImage;StillImage  COORDINATE_ROUNDED
# 101719                                   StillImage                 NaN
# 103400                        StillImage;StillImage  COORDINATE_ROUNDED
# 107116  StillImage;StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 111392                        StillImage;StillImage  COORDINATE_ROUNDED
# 117538                                   StillImage  COORDINATE_ROUNDED
# 119158             StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 122706                                   StillImage  COORDINATE_ROUNDED
# 125532                                   StillImage  COORDINATE_ROUNDED
# 125628                        StillImage;StillImage  COORDINATE_ROUNDED
# 126228             StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 129818                                   StillImage                 NaN
# 134137                        StillImage;StillImage  COORDINATE_ROUNDED
# 135522                                   StillImage  COORDINATE_ROUNDED
# 135711                                   StillImage  COORDINATE_ROUNDED
# 137610             StillImage;StillImage;StillImage  COORDINATE_ROUNDED
# 141418                                   StillImage  COORDINATE_ROUNDED
#
#                               geometry
# 2201    POINT (1896122.417 607152.305)
# 7013    POINT (1838083.714 607598.964)
# 10105   POINT (1878580.066 601568.502)
# 10215   POINT (1812971.008 634034.974)
# 11666   POINT (1843906.512 603461.624)
# 13170   POINT (1809199.110 638230.512)
# 13965   POINT (1785386.106 653887.969)
# 15564   POINT (1816952.711 626418.168)
# 17353   POINT (1882120.081 602351.215)
# 18116   POINT (1876546.414 601756.856)
# 21552   POINT (1811907.424 625085.870)
# 23709   POINT (1896388.152 608602.399)
# 30982   POINT (1820041.685 628245.196)
# 32114   POINT (1878111.522 600118.235)
# 47626   POINT (1886942.699 600884.113)
# 51240   POINT (1844911.696 607554.762)
# 55444   POINT (1833890.850 617171.278)
# 59498   POINT (1886410.403 606519.756)
# 62806   POINT (1878183.162 600655.758)
# 67771   POINT (1800307.818 628598.413)
# 68075   POINT (1885674.624 607721.909)
# 68931   POINT (1878043.663 601463.302)
# 69564   POINT (1808687.731 629838.418)
# 73228   POINT (1837792.449 607857.686)
# 73589   POINT (1876657.177 602650.163)
# 76180   POINT (1881284.111 596665.552)
# 77424   POINT (1812246.288 634083.563)
# 87959   POINT (1893351.282 605987.947)
# 88021   POINT (1889751.265 588571.373)
# 91075   POINT (1813198.347 636797.437)
# 91482   POINT (1813747.129 627252.933)
# 92300   POINT (1776252.833 648906.390)
# 93191   POINT (1795221.258 612788.789)
# 95176   POINT (1893214.143 594757.044)
# 97508   POINT (1803515.939 619904.054)
# 101186  POINT (1842753.818 609279.202)
# 101272  POINT (1838064.626 608092.984)
# 101719  POINT (1813109.078 634268.049)
# 103400  POINT (1812979.480 641876.405)
# 107116  POINT (1874180.161 630730.196)
# 111392  POINT (1812927.347 633775.907)
# 117538  POINT (1817296.499 629823.532)
# 119158  POINT (1881096.923 602542.261)
# 122706  POINT (1818667.410 621427.623)
# 125532  POINT (1813047.499 634209.497)
# 125628  POINT (1813340.888 633447.981)
# 126228  POINT (1882793.330 604685.538)
# 129818  POINT (1890061.215 589675.436)
# 134137  POINT (1895726.946 605401.841)
# 135522  POINT (1850645.730 606711.408)
# 135711  POINT (1880180.247 609850.817)
# 137610  POINT (1876716.330 601978.007)
# 141418  POINT (1842895.631 607451.276)
#
# [53 rows x 51 columns]

# %%
ucsb_df = pd.DataFrame(
    {'Location': ['Bren Hall'],
     'Latitude': [34.413059],
     'Longitude': [-119.841826]})

ucsb_gdf = gpd.GeoDataFrame(
    ucsb_df, geometry=gpd.points_from_xy(ucsb_df.Longitude, ucsb_df.Latitude), crs={"init":"EPSG:4326"})

ucsb_gdf = ucsb_gdf.to_crs("EPSG:6423")

ucsb_buffer = ucsb_gdf.buffer(16090).unary_union

friendly_neighbors = tarantulas_rpj["geometry"].within(ucsb_buffer)

friendly_neighbors
